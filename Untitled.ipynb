# %%
import random
import math

# %%
N = 100.0

# %%
for i in range(2, int(N / 2)):
    # rand = random.randrange(2, N / 2)
    rand = float(i)
    
    div = N / rand
    
    m = math.ceil(div)
    
    print(rand)
    print(div)
    print(rand * m - N)
    
    print("--")
    
    # if(div.is_integer()):
    #     print("Found factor:", rand)
    #     break
# Out:
# 2.0
# 50.0
# 0.0
# --
# 3.0
# 33.333333333333336
# 2.0
# --
# 4.0
# 25.0
# 0.0
# --
# 5.0
# 20.0
# 0.0
# --
# 6.0
# 16.666666666666668
# 2.0
# --
# 7.0
# 14.285714285714286
# 5.0
# --
# 8.0
# 12.5
# 4.0
# --
# 9.0
# 11.11111111111111
# 8.0
# --
# 10.0
# 10.0
# 0.0
# --
# 11.0
# 9.090909090909092
# 10.0
# --
# 12.0
# 8.333333333333334
# 8.0
# --
# 13.0
# 7.6923076923076925
# 4.0
# --
# 14.0
# 7.142857142857143
# 12.0
# --
# 15.0
# 6.666666666666667
# 5.0
# --
# 16.0
# 6.25
# 12.0
# --
# 17.0
# 5.882352941176471
# 2.0
# --
# 18.0
# 5.555555555555555
# 8.0
# --
# 19.0
# 5.2631578947368425
# 14.0
# --
# 20.0
# 5.0
# 0.0
# --
# 21.0
# 4.761904761904762
# 5.0
# --
# 22.0
# 4.545454545454546
# 10.0
# --
# 23.0
# 4.3478260869565215
# 15.0
# --
# 24.0
# 4.166666666666667
# 20.0
# --
# 25.0
# 4.0
# 0.0
# --
# 26.0
# 3.8461538461538463
# 4.0
# --
# 27.0
# 3.7037037037037037
# 8.0
# --
# 28.0
# 3.5714285714285716
# 12.0
# --
# 29.0
# 3.4482758620689653
# 16.0
# --
# 30.0
# 3.3333333333333335
# ...

# %%
# Out:
# 11
